# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('marketing_customer_analysis.xlsx')

display(data.shape)
display(data.head())
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
display(data.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
data2 = data.copy()

cols = []
for column in data2.columns:
    cols.append(column.lower().capitalize().replace(" ","_"))
data2.columns = cols  

data2 = data2.rename({'Employmentstatus':'Employment_status'})

display(data2.columns)

customer = data2.copy()
# Out:
# Index(['Customer', 'State', 'Customer_lifetime_value', 'Response', 'Coverage',
#        'Education', 'Effective_to_date', 'Employmentstatus', 'Gender',
#        'Income', 'Location_code', 'Marital_status', 'Monthly_premium_auto',
#        'Months_since_last_claim', 'Months_since_policy_inception',
#        'Number_of_open_complaints', 'Number_of_policies', 'Policy_type',
#        'Policy', 'Renew_offer_type', 'Sales_channel', 'Total_claim_amount',
#        'Vehicle_class', 'Vehicle_size'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# Customer                          object
# State                             object
# Customer_lifetime_value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective_to_date                 object
# Employmentstatus                  object
# Gender                            object
# Income                             int64
# Location_code                     object
# Marital_status                    object
# Monthly_premium_auto               int64
# Months_since_last_claim            int64
# Months_since_policy_inception      int64
# Number_of_open_complaints          int64
# Number_of_policies                 int64
# Policy_type                       object
# Policy                            object
# Renew_offer_type                  object
# Sales_channel                     object
# Total_claim_amount               float64
# Vehicle_class                     object
# ...

# %%
data2.isna().sum()
# Out:
# Customer                         0
# State                            0
# Customer_lifetime_value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective_to_date                0
# Employmentstatus                 0
# Gender                           0
# Income                           0
# Location_code                    0
# Marital_status                   0
# Monthly_premium_auto             0
# Months_since_last_claim          0
# Months_since_policy_inception    0
# Number_of_open_complaints        0
# Number_of_policies               0
# Policy_type                      0
# Policy                           0
# Renew_offer_type                 0
# Sales_channel                    0
# Total_claim_amount               0
# Vehicle_class                    0
# Vehicle_size                     0
# dtype: int64

# %%
data2['State'].value_counts(dropna=False)
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: State, dtype: int64

# %%
data2['State']=data2['State'].fillna('California')
display(data2['State'].value_counts(dropna=False))
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: State, dtype: int64

# %% [markdown]
# Because the states here are ojects so I just filled all the missing values with the mode - California.

# %%
data2['Months_since_last_claim'].value_counts(dropna=False)
# Out:
# 3     381
# 6     364
# 1     345
# 4     335
# 7     333
# 2     329
# 0     314
# 5     313
# 10    306
# 11    297
# 16    295
# 15    286
# 13    285
# 8     279
# 12    273
# 14    268
# 17    263
# 9     250
# 19    246
# 23    239
# 25    236
# 21    233
# 20    231
# 18    229
# 22    218
# 24    211
# 29    206
# 28    201
# 31    190
# 26    186
# 30    182
# 27    182
# 33    179
# 34    169
# 35    142
# 32    138
# Name: Months_since_last_claim, dtype: int64

# %%
data2=data2[(data2['Months_since_last_claim']<=24.0) | (data2['Response']=='Yes')]
display(data2['Months_since_last_claim'].value_counts(dropna=False))
# Out:
# 3     381
# 6     364
# 1     345
# 4     335
# 7     333
# 2     329
# 0     314
# 5     313
# 10    306
# 11    297
# 16    295
# 15    286
# 13    285
# 8     279
# 12    273
# 14    268
# 17    263
# 9     250
# 19    246
# 23    239
# 21    233
# 20    231
# 18    229
# 22    218
# 24    211
# 25     42
# 28     36
# 35     24
# 31     24
# 29     24
# 34     24
# 30     18
# 32     18
# 33     18
# 27     12
# 26     12
# Name: Months_since_last_claim, dtype: int64

# %% [markdown]
# All claims that were made more than 24 months ago and from cutomers who have not responsed yet are excluded due to their inactivity. The other Nah values are kept nevertheless.

# %%
data2['Number_of_open_complaints'].describe()
# Out:
# count    7375.000000
# mean        0.384136
# std         0.916854
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         5.000000
# Name: Number_of_open_complaints, dtype: float64

# %%
data2['Number_of_open_complaints']=data2['Number_of_open_complaints'].fillna(data2['Number_of_open_complaints'].median())
display(data2['Number_of_open_complaints'].value_counts())
# Out:
# 0    5874
# 1     798
# 2     291
# 3     244
# 4     119
# 5      49
# Name: Number_of_open_complaints, dtype: int64

# %% [markdown]
# Based on the statistical outputs of the variable, the data follows the pattern of a positively-skewed distribution. That means, the mean value is greater than the median and the median is greater than the mode. So I replaced all the Nah values with the median value.

# %%
data2['Effective_to_date'] = pd.to_datetime(data2['Effective_to_date'], errors='coerce')
data2['Effective_month'] = data2['Effective_to_date'].dt.strftime('%B')
display(data2.head())
display(data2['Effective_month'].value_counts(dropna=False))
# Out:
#   Customer       State  Customer_lifetime_value Response  Coverage Education  \
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
# 5  OC83172      Oregon              8256.297800      Yes     Basic  Bachelor
#
#   Effective_to_date Employmentstatus Gender  Income  ...  \
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
# 5        2011-01-25         Employed      F   62902  ...
#
#   Number_of_open_complaints Number_of_policies     Policy_type        Policy  \
# 1                         0                  8   Personal Auto   Personal L3
# ...

# %% [markdown]
# No need to furthr filter as all the months recorded are in Q1.

# %%
def clean(dataset):
    dataset=data.copy()
    dataset = dataset.rename({'Employmentstatus':'Employment_status'})
    col1=[]
    for column in dataset.columns:
        col1.append(column.lower().capitalize().replace(" ","_"))
    dataset.columns=col1
    dataset['State']=dataset['State'].fillna('California')
    dataset=dataset[(dataset['Months_since_last_claim']<=24.0) | (dataset['Response']=='Yes')]
    dataset['Number_of_open_complaints']=dataset['Number_of_open_complaints'].fillna(data2['Number_of_open_complaints'].median())
    dataset['Effective_to_date'] = pd.to_datetime(data2['Effective_to_date'], errors='coerce')
    dataset['Effective_month'] = dataset['Effective_to_date'].dt.strftime('%B')
    dataset.reset_index(drop=True,inplace=True)
    return dataset

# %%
data3 = data.copy()
display(clean(data3))
display(data3.shape)
# Out:
#      Customer       State  Customer_lifetime_value Response  Coverage  \
# 0     QZ44356     Arizona              6979.535903       No  Extended
# 1     AI49188      Nevada             12887.431650       No   Premium
# 2     WW63253  California              7645.861827       No     Basic
# 3     HB64268  Washington              2813.692575       No     Basic
# 4     OC83172      Oregon              8256.297800      Yes     Basic
# ...       ...         ...                      ...      ...       ...
# 7370  YM19146  California              4100.398533       No   Premium
# 7371  LA72316  California             23405.987980       No     Basic
# 7372  PK87824  California              3096.511217      Yes  Extended
# 7373  TD14365  California              8163.890428       No  Extended
# 7374  Y167826  California              2611.836866       No  Extended
#
#      Education Effective_to_date Employmentstatus Gender  Income  ...  \
# ...

# %% [markdown]
# Included all in one function.

# %%
data3['Sales Channel']
# Out:
# 0             Agent
# 1             Agent
# 2             Agent
# 3       Call Center
# 4             Agent
#            ...
# 9129            Web
# 9130         Branch
# 9131         Branch
# 9132         Branch
# 9133    Call Center
# Name: Sales Channel, Length: 9134, dtype: object

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
data3.describe(include='all').T
# Out:
#                                 count unique            top  freq  \
# Customer                         9134   9134        BU79786     1
# State                            9134      5     California  3150
# Customer Lifetime Value        9134.0    NaN            NaN   NaN
# Response                         9134      2             No  7826
# Coverage                         9134      3          Basic  5568
# Education                        9134      5       Bachelor  2748
# Effective To Date                9134     59        1/10/11   195
# EmploymentStatus                 9134      5       Employed  5698
# Gender                           9134      2              F  4658
# Income                         9134.0    NaN            NaN   NaN
# Location Code                    9134      3       Suburban  5779
# Marital Status                   9134      3        Married  5298
# Monthly Premium Auto           9134.0    NaN            NaN   NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

sns.countplot(data=data3, x="Response")
plt.show()

# %%
sns.countplot(data=data3, x="Sales Channel")
plt.show()

# %%
sns.distplot(x = data3["Total Claim Amount"], bins = 50)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(x=data3['Income'], bins=50)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data3['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
y = [1308,7826]
label1=['Yes','No']
plt.pie(y,labels=label1)
plt.show()

# %%
data3['Sales Channel'].value_counts()
# Out:
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: Sales Channel, dtype: int64

# %%
z = [3477,2567,1765,1325]
label2=['Agent','Branch','Call Center','Web']
plt.pie(z,labels=label2)
plt.show()

# %%
fig, ax = plt.subplots(2,2,figsize=(10,10))
ax[0,0].pie(y,labels=label1)
ax[0,0].set_xlabel('Response')
ax[0,0].set_ylabel("Count")
ax[0,0].set_title("Number of responses")
ax[0,1].pie(z,labels=label2)
ax[0,1].set_xlabel('Sales channels')
ax[0,1].set_ylabel("")
ax[0,1].set_title("Response rate by the sales channel")
ax[1,0].hist (data3['Total Claim Amount'],bins=10)
ax[1,0].set_xlabel('Total Claim Amount')
ax[1,0].set_ylabel("Count")
ax[1,0].set_title("Total Claim Amount Distribution")
ax[1,1].hist (data3['Income'],bins=10)
ax[1,1].set_xlabel('Income')
ax[1,1].set_ylabel("Count")
ax[1,1].set_title("Income Distribution")
plt.tight_layout()
plt.show()
